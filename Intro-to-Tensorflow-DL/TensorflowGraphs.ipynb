# %% [markdown]
# ## Tensorflow Graphs

# %%
import tensorflow as tf

# %%
# Node-1 Input to Graph
n1 = tf.constant(1)

# %%
# Node-2 Input to Graph
n2 = tf.constant(2)

# %%
# Node-3 Addition of Previous Two Nodes
n3 = n1 + n2

# %%
type(n3)
# Out:
# tensorflow.python.framework.ops.Tensor

# %%
# Run the Node-3
with tf.Session() as sess:
    result = sess.run(n3)

# %%
print(result)
# Out:
# 3

# %%
print(n3)
# Out:
# Tensor("add:0", shape=(), dtype=int32)

# %% [markdown]
# ### Create Additional Graphs in Addition to Default Graph

# %%
# Current Default Graph
print(tf.get_default_graph())
# Out:
# <tensorflow.python.framework.ops.Graph object at 0x7f5f02b7a908>

# %%
# Create a New Graph
g = tf.Graph()

# %%
print(g)
# Out:
# <tensorflow.python.framework.ops.Graph object at 0x7f5f02b82c88>

# %%
# Set New Graph as Default Graph
graph_one = tf.get_default_graph()

# %%
# New Graph
graph_two = tf.Graph()

# %%
# Set Graph 2 as Default Graph
with graph_two.as_default():
    print(graph_two is tf.get_default_graph())
# Out:
# True
